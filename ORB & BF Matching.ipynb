# %%
import cv2
import cv2 as cv
import numpy as np
from PIL import Image

# Read two images in grayscale image
img1 = cv2.imread("image1.png", cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread("image2.png", cv2.IMREAD_GRAYSCALE)
 
#Create ORB feature detectors and descriptors
orb = cv2.ORB_create(nfeatures=1000)

#Detect features and descriptors for two images
keypoint1, descriptor1 = orb.detectAndCompute(img1, None)
keypoint2, descriptor2 = orb.detectAndCompute(img2, None)

# Get a violent matcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#Using a matcher to match the similarity of two descriptors in Chengdu
maches = bf.match(descriptor1, descriptor2)
# Sort by proximity
maches = sorted(maches, key=lambda x: x.distance)
# Draw a match
img3 = cv2.drawMatches(img1, keypoint1, img2, keypoint2, maches[: 30], img2, flags=2)

display(Image.fromarray(img3))
# Out:
# <PIL.Image.Image image mode=RGB size=2150x761 at 0x17E5AD314F0>

# %%
akaze = cv.AKAZE_create()

#Detect features and descriptors for two images
keypoint1, descriptor1 = akaze.detectAndCompute(img1, None)
keypoint2, descriptor2 = akaze.detectAndCompute(img2, None)

# Get a violent matcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#Using a matcher to match the similarity of two descriptors in Chengdu
maches = bf.match(descriptor1, descriptor2)
# Sort by proximity
maches = sorted(maches, key=lambda x: x.distance)
# Draw a match
img3 = cv2.drawMatches(img1, keypoint1, img2, keypoint2, maches[: 30], img2, flags=2)

display(Image.fromarray(img3))
# Out:
# <PIL.Image.Image image mode=RGB size=2150x761 at 0x17E53616A90>
